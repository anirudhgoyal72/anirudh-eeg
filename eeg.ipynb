# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('subject-info.csv')

# %%
df.head()
# Out:
#      Subject  Age Gender  Recording year  Number of subtractions  \
# 0  Subject00   21      F            2011                    9.70
# 1  Subject01   18      F            2011                   29.35
# 2  Subject02   19      F            2012                   12.88
# 3  Subject03   17      F            2010                   31.00
# 4  Subject04   17      F            2010                    8.60
#
#    Count quality
# 0              0
# 1              1
# 2              1
# 3              1
# 4              0

# %%
rt=df.drop(['Age','Gender','Recording year','Number of subtractions'],axis=1)

# %%
rt['Count quality'].value_counts()
# Out:
# 1    26
# 0    10
# Name: Count quality, dtype: int64

# %%
rt=rt.drop([16,17,18,20,23,24,25,26,27,28,29,31,32,33,34,35],axis=0)

# %%
rt
# Out:
#       Subject  Count quality
# 0   Subject00              0
# 1   Subject01              1
# 2   Subject02              1
# 3   Subject03              1
# 4   Subject04              0
# 5   Subject05              1
# 6   Subject06              0
# 7   Subject07              1
# 8   Subject08              1
# 9   Subject09              0
# 10  Subject10              0
# 11  Subject11              1
# 12  Subject12              1
# 13  Subject13              1
# 14  Subject14              0
# 15  Subject15              1
# 19  Subject19              0
# 21  Subject21              0
# 22  Subject22              0
# 30  Subject30              0

# %%
import mne

# %%
raw = mne.io.read_raw_edf("Subject00_2.edf", preload=True)
# Out:
# Extracting EDF parameters from C:\Users\LENOVO\Subject00_2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 30999  =      0.000 ...    61.998 secs...

# %%
raw
# Out:
# <RawEDF | Subject00_2.edf, 21 x 31000 (62.0 s), ~5.0 MB, data loaded>

# %%
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 21 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 21
#  projs: []
#  sfreq: 500.0 Hz
# >

# %%
import pyedflib

# %%
from pyedflib import highlevel

# %%
x,y,z=highlevel.read_edf('Subject00_2.edf')

# %%
highlevel.drop_channels('Subject00_2.edf',to_drop=['EEG A2-A1','ECG ECG','EDF Annotations'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-6816e6165bdc> in <module>
# ----> 1 highlevel.drop_channels('Subject00_2.edf',to_drop=['EEG A2-A1','ECG ECG','EDF Annotations'])
#
# ~\Anaconda3\lib\site-packages\pyedflib\highlevel.py in drop_channels(edf_source, edf_target, to_keep, to_drop)
#     617         for i,ch in enumerate(to_drop):
#     618             if isinstance(ch,str):
# --> 619                 ch_idx = ch_names.index(ch.lower())
#     620                 to_drop[i] = ch_idx
#     621         to_drop = [len(ch_nrs)+ch if ch<0 else ch for ch in to_drop]
#
# ValueError: 'edf annotations' is not in list

# %%
import mne

# %%
highlevel.drop_channels('Subject00_2.edf',to_drop=['EEG A2-A1','ECG ECG'])
# Out:
# []
# C:\Users\LENOVO\Anaconda3\lib\site-packages\pyedflib\highlevel.py:603: UserWarning: Target file will be overwritten
#   warnings.warn('Target file will be overwritten')
# 'Subject00_2_dropped.edf'

# %%
import os

# %%
files6=[]

# %%
for i in os.listdir('C:\\Users\\LENOVO'):
    if i.endswith('.edf'):
        files6.append(i)

# %%
files6
# Out:
# ['Subject00_2.edf',
#  'Subject00_2_dropped.edf',
#  'Subject01_2.edf',
#  'Subject01_2_dropped.edf',
#  'Subject02_2.edf',
#  'Subject02_2_dropped.edf',
#  'Subject03_2.edf',
#  'Subject03_2_dropped.edf',
#  'Subject04_2.edf',
#  'Subject04_2_dropped.edf',
#  'Subject05_2.edf',
#  'Subject05_2_dropped.edf',
#  'Subject06_2.edf',
#  'Subject06_2_dropped.edf',
#  'Subject07_2.edf',
#  'Subject07_2_dropped.edf',
#  'Subject08_2.edf',
#  'Subject08_2_dropped.edf',
#  'Subject09_2.edf',
#  'Subject09_2_dropped.edf',
#  'Subject10_2.edf',
#  'Subject10_2_dropped.edf',
#  'Subject11_2.edf',
#  'Subject11_2_dropped.edf',
#  'Subject12_2.edf',
#  'Subject12_2_dropped.edf',
#  'Subject13_2.edf',
#  'Subject13_2_dropped.edf',
#  'Subject14_2.edf',
#  'Subject14_2_dropped.edf',
#  'Subject15_2.edf',
#  'Subject15_2_dropped.edf',
#  'Subject19_2.edf',
#  'Subject19_2_dropped.edf',
#  'Subject21_2.edf',
#  'Subject21_2_dropped.edf',
#  'Subject22_2.edf',
#  'Subject22_2_dropped.edf',
# ...

# %%
files7=[]
for i in files6:
    if i.endswith('2.edf'):
        files7.append(i)

# %%
for i in files3:
    raw = mne.io.read_raw_edf(i, preload=True)
    print(raw.info)
# Out:
# Extracting EDF parameters from C:\Users\LENOVO\Subject00_2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 30999  =      0.000 ...    61.998 secs...
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 21 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 21
#  projs: []
#  sfreq: 500.0 Hz
# >
# Extracting EDF parameters from C:\Users\LENOVO\Subject00_2_dropped.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 30999  =      0.000 ...    61.998 secs...
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
# ...

# %%
files7
# Out:
# ['Subject00_2.edf',
#  'Subject01_2.edf',
#  'Subject02_2.edf',
#  'Subject03_2.edf',
#  'Subject04_2.edf',
#  'Subject05_2.edf',
#  'Subject06_2.edf',
#  'Subject07_2.edf',
#  'Subject08_2.edf',
#  'Subject09_2.edf',
#  'Subject10_2.edf',
#  'Subject11_2.edf',
#  'Subject12_2.edf',
#  'Subject13_2.edf',
#  'Subject14_2.edf',
#  'Subject15_2.edf',
#  'Subject19_2.edf',
#  'Subject21_2.edf',
#  'Subject22_2.edf',
#  'Subject30_2.edf']

# %%
files10=[]
for i in files6:
    if i.endswith('dropped.edf'):
        files10.append(i)

# %%
highlevel.drop_channels('Subject00_2.edf',to_drop=['EEG A2-A1','ECG ECG'])

# %%
files10
# Out:
# ['Subject00_2_dropped.edf',
#  'Subject01_2_dropped.edf',
#  'Subject02_2_dropped.edf',
#  'Subject03_2_dropped.edf',
#  'Subject04_2_dropped.edf',
#  'Subject05_2_dropped.edf',
#  'Subject06_2_dropped.edf',
#  'Subject07_2_dropped.edf',
#  'Subject08_2_dropped.edf',
#  'Subject09_2_dropped.edf',
#  'Subject10_2_dropped.edf',
#  'Subject11_2_dropped.edf',
#  'Subject12_2_dropped.edf',
#  'Subject13_2_dropped.edf',
#  'Subject14_2_dropped.edf',
#  'Subject15_2_dropped.edf',
#  'Subject19_2_dropped.edf',
#  'Subject21_2_dropped.edf',
#  'Subject22_2_dropped.edf',
#  'Subject30_2_dropped.edf']

# %%
for i in files10:
    print(raw.info)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
# ...

# %%
for i in files10:
    raw.filter(0.5,45,picks=None)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 3301 samples (6.602 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# ...

# %%
for i in files10:
    print(raw.info)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
# ...

# %%
for i in files10:
    raw.crop(0,59.980).load_data()

# %%
for i in files10:
    print(raw.info)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 45.0 Hz
#  meas_date: 2011-01-01 00:00:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG Fp2, EEG F3, EEG F4, EEG F7, EEG F8, EEG T3, EEG ...
# ...

# %%
for i in files10:
    print(raw)
# Out:
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# <RawEDF | Subject30_2_dropped.edf, 19 x 29991 (60.0 s), ~4.4 MB, data loaded>
# ...

# %%
files12=[]
for i in files10:
    events= mne.events_from_annotations(raw)
    print(events)
    files12.append(events)
# Out:
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})
# (array([], shape=(0, 3), dtype=int32), {})

# %%
print(files12)
# Out:
# [(array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {}), (array([], shape=(0, 3), dtype=int32), {})]

# %%
for i in files12:
    print(i[0][1],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-216-4cb833e7e3d9> in <module>
#       1 for i in files12:
# ----> 2     print(i[0][1],axis=1)
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
mean1=[]

# %%
for i i
